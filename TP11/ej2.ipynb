# %% [markdown]
# Ejercicio 2

# %% [markdown]
# Representa las ventas mensuales de una librería.

# %% [markdown]
# ```
# Meses: ["Ene", "Feb", "Mar", "Abr", "May"]
# Ventas: [150, 200, 180, 220, 170]
# ```

# %% [markdown]
# * Etiqueta los ejes
# * Asigna un color diferente a cada barra
# * Muestra el valor de cada barra sobre ella
