# %% [markdown]
# Ejercicio 1

# %% [markdown]
# Dibuja un gráfico de línea que muestre el crecimiento de una planta a lo largo de 6 días.

# %% [markdown]
# Días: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Altura (cm): [2, 3.5, 5, 7, 8.5, 10]

# %% [markdown]
# * Agrega título: "Crecimiento de una planta"
# * Eje X: "Días”
# * Eje Y: "Altura (cm)"
# * Cambia el color de la línea a verde
# * Agrega puntos marcados en la línea

# %%
import matplotlib.pyplot as plt

dias = [1, 2, 3, 4, 5, 6]
altura = [2, 3.5, 5, 7, 8.5, 10]

plt.plot(dias, altura, color='green', marker='o')
plt.title("Crecimiento de una planta")
plt.xlabel("Días")
plt.ylabel("Altura (cm)")
plt.grid(True)
plt.show()
