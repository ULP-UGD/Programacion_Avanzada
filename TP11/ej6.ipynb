# %% [markdown]
# Ejercicio 6

# %% [markdown]
# Un grupo de investigadores ha registrado la edad y el nivel de colesterol de 10 pacientes.
# Representa visualmente la relación entre ambas variables usando un gráfico de dispersión.

# %% [markdown]
# ```
# edades = [25, 32, 40, 50, 45, 60, 37, 29, 55, 48]
# colesterol = [180, 190, 210, 240, 220, 260, 200, 185, 250, 230]
# ```

# %% [markdown]
# Crea un gráfico de dispersión donde:
# * El eje X represente la edad de los pacientes.
# * El eje Y represente su nivel de colesterol.
# * Título: "Relación entre edad y nivel de colesterol"
# * Eje X: "Edad (años)"
# * Eje Y: "Colesterol (mg/dL)"
# * Usa color rojo ('red') para los puntos.
# * Agrega una rejilla al gráfico.
# * Aumenta el tamaño de los puntos (por ejemplo, s=60).

# %%
import matplotlib.pyplot as plt

edades = [25, 32, 40, 50, 45, 60, 37, 29, 55, 48]
colesterol = [180, 190, 210, 240, 220, 260, 200, 185, 250, 230]

plt.scatter(edades, colesterol, color='red', s=60)

plt.xlabel('Edad (años)')
plt.ylabel('Colesterol (mg/dL)')
plt.title('Relación entre edad y nivel de colesterol')

plt.grid(True)

plt.show()
