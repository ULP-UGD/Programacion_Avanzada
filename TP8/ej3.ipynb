# %% [markdown]
# Ejercicio 3

# %% [markdown]
# Dada una serie de Pandas que contiene los siguientes valores: [18, 22, 7, 9, 15, 8], filtra y muestra solo aquellos valores que sean pares.

# %%
import pandas as pd
from IPython.display import display

valores=pd.Series([18,22,7,9,15,8])

# %%
print("Serie original:")
display(valores)
# Out:
# Serie original:
# 0    18
# 1    22
# 2     7
# 3     9
# 4    15
# 5     8
# dtype: int64

# %% [markdown]
# 1. Primero, crea una serie de valores booleanos que represente la condición. Nombra a esta variable como: condicion_valores_pares

# %%
condicion_valores_pares=valores%2==0
print("\n Condición de valores pares:")
display(condicion_valores_pares)
# Out:
#  Condición de valores pares:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# 2. Luego aplica esta serie para filtrar los valores originales.

# %%
valores_pares=valores[condicion_valores_pares]
print("\n Valores pares:")
display(valores_pares)
# Out:
#  Valores pares:
# 0    18
# 1    22
# 5     8
# dtype: int64
