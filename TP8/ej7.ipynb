# %% [markdown]
# Ejercicio 7

# %% [markdown]
# Crea un DataFrame llamado datos_clima usando Pandas para cargar un archivo CSV
# llamado "clima.csv" que contiene datos sobre temperaturas y precipitaciones en diferentes ciudades. Asegúrate de importar Pandas antes de intentar cargar el archivo.

# %% [markdown]
# Considera que tu archivo "clima.csv" se encuentra en la misma ubicación que el archivo de tu código, por lo cual puedes importarlo usando su nombre incluyendo la extensión .csv

# %%
import pandas as pd
datos_clima=pd.read_csv('https://raw.githubusercontent.com/ULP-UGD/Programacion_Avanzada/refs/heads/main/TP8/clima.csv')

# %% [markdown]
# 1. Aplica el método  describe() para explorar la estructura del DataFrame y obtener un resumen estadístico de las columnas numéricas.

# %% [markdown]
# 2. Asegurate de almacenar el resultado en una variable llamada  describe_df

# %%
describe_df = datos_clima.describe()

# %% [markdown]
# 3. Extraer exactamente la primera fila de 'datos_clima'. Almacena el contenido en una variable llamada head_df

# %%
head_df = datos_clima.head(1)

# %%
print(head_df)
# Out:
#         fecha  temperatura_max  temperatura_min  humedad  precipitacion  \
# 0  2025-05-01               25               15       60            2.5
#
#          ciudad
# 0  Buenos Aires

# %% [markdown]
# 4. Extraer exactamente la última fila de 'datos_clima'. Almacena el contenido en una variable llamada tail_df

# %%
tail_df = datos_clima.tail(1)

# %%
print(tail_df)
# Out:
#         fecha  temperatura_max  temperatura_min  humedad  precipitacion  \
# 9  2025-05-05               17                9       90            7.0
#
#     ciudad
# 9  Córdoba
