# %% [markdown]
# Ejercicio 6

# %% [markdown]
# Dado el DataFrame df_empleados creado en el ejercicio anterior:

# %% [markdown]
# ● La columna nombre debe contener los nombres de tres empleados: 'Ana', 'Luis' y 'Carlos'

# %% [markdown]
# ● La columna edad debe contener las edades correspondientes: 30, 25 y 40

# %%
import pandas as pd

# Crear el DataFrame
data = {'nombre': ['Ana', 'Luis', 'Carlos'],
        'edad': [30, 25, 40]}
df_empleados = pd.DataFrame(data)

# Mostrar el DataFrame
print(df_empleados)
# Out:
#    nombre  edad
# 0     Ana    30
# 1    Luis    25
# 2  Carlos    40

# %% [markdown]
# 1. Utiliza el método adecuado para seleccionar solo la columna edad y almacénala en una variable llamada edades.

# %%
edades = df_empleados['edad']

# %% [markdown]
# 2. Luego, muestra el contenido de edades utilizando la función print().

# %%
print(edades)
# Out:
# 0    30
# 1    25
# 2    40
# Name: edad, dtype: int64

# %% [markdown]
# 3. Asegúrate de demostrar que el tipo de dato de edades es una Serie de Pandas.
# Utilizando la función type().

# %%
print(type(edades))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# 4. Explorar sus atributos principales: shape, columns, y index utilizando las
# siguientes variables respectivamente: shape_df, columns_df, index_df Imprime
# los resultados de cada variable..

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
shape_df = df_empleados.shape
columns_df = df_empleados.columns
index_df = df_empleados.index

print(shape_df)
print(columns_df)
print(index_df)

shape_edades = edades.shape
columns_edades = edades.name
index_edades = edades.index
# Out:
# (3, 2)
# Index(['nombre', 'edad'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)
